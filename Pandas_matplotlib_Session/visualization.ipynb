# %% [markdown]
# ## Visualisation

# %% [markdown]
# * Data Exploration
# * Identifies Patterns and Trends
# * Enhances Understanding

# %%
# plot, legend, subplot, xlim, ylim, show , figure

# %% [markdown]
# Here's a graph meme related to the life of a graduate student
#
# * Week 1: High energy and enthusiasm for the semester.
# * Midterms Week: Energy dips as midterms approach.
# * Week 8: Energy gradually declines due to coursework and research.
# * Week 14: Energy hits its lowest point during finals.
# * End of Semester: Energy spikes briefly as the semester ends, followed by exhaustion.

# %%
import matplotlib.pyplot as plt

month_number = [1, 2, 3, 4, 5, 6, 7]
energy = [500, 200, 300,600, 400, 100,400]
workload = [100, 250, 350,100, 450, 150,800]
ax =plt.plot(month_number, energy)
ax =plt.plot(month_number, workload)
plt.ticklabel_format(axis='y', style='plain')
plt.title('Energy/Workload By Month')
plt.xlabel('Month Number')
plt.ylabel('Energy/workload')
plt.show()

# %%
year_number = [2020, 2021 , 2022 , 2023]
trend = [50,  5000,500,100]
plt.plot(year_number, trend)
plt.ticklabel_format(axis='y', style='plain')
plt.title('Trend By Year')
plt.xlabel('Year')
plt.ylabel('Trend')
plt.savefig('meme.jpg')

# %%
## 1. Bike Sharing Time Series ##

import pandas as pd


bike_sharing=pd.read_csv("day.csv",encoding="latin-1")

# %%
# instant: record index
# 	- dteday : date
# 	- season : season (1:springer, 2:summer, 3:fall, 4:winter)
# 	- yr : year (0: 2011, 1:2012)
# 	- mnth : month ( 1 to 12)
# 	- hr : hour (0 to 23)
# 	- holiday : weather day is holiday or not (extracted from http://dchr.dc.gov/page/holiday-schedule)
# 	- weekday : day of the week
# 	- workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# 	+ weathersit : 
# 		- 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 		- 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 		- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 		- 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# 	- temp : Normalized temperature in Celsius. The values are divided to 41 (max)
# 	- atemp: Normalized feeling temperature in Celsius. The values are divided to 50 (max)
# 	- hum: Normalized humidity. The values are divided to 100 (max)
# 	- windspeed: Normalized wind speed. The values are divided to 67 (max)
# 	- casual: count of casual users
# 	- registered: count of registered users
# 	- cnt: count of total rental bikes including both casual and registered

# %%
print(bike_sharing.head(5))


## 2. Exploring Data ##
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
print(bike_sharing.tail(5))
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %%
print(bike_sharing.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
# None

# %%
bike_sharing.shape
# Out:
# (731, 16)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#scatter plot

# %%
bike_sharing = pd.read_csv('day.csv')
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])
plt.scatter(bike_sharing['windspeed'],bike_sharing['cnt'])
plt.xlabel("Wind Speed")
plt.ylabel("Bikes Rented")
plt.show()

# %%
bike_sharing = pd.read_csv('day.csv')
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])
plt.scatter(bike_sharing['atemp'],bike_sharing['registered'])
plt.show()

correlation="positive"

# %%
bike_sharing = pd.read_csv('day.csv')
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])

bike_sharing.info()
temp_atemp_corr=bike_sharing['temp'].corr(bike_sharing['atemp'])
wind_hum_corr=bike_sharing['windspeed'].corr(bike_sharing['hum'])

plt.scatter(bike_sharing['temp'],bike_sharing['atemp'])
plt.xlabel("Air Temperature")
plt.ylabel("Feeling Temperature")
plt.show()

plt.scatter(bike_sharing['windspeed'],bike_sharing['hum'])
plt.xlabel("Wind Speed")
plt.ylabel("Humidity")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
#set type
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])


bike_sharing.corr()["weathersit"]
# Out:
# instant      -0.021477
# dteday       -0.021477
# season        0.019211
# yr           -0.048727
# mnth          0.043528
# holiday      -0.034627
# weekday       0.031087
# workingday    0.061200
# weathersit    1.000000
# temp         -0.120602
# atemp        -0.121583
# hum           0.591045
# windspeed     0.039511
# casual       -0.247353
# registered   -0.260388
# cnt          -0.297391
# Name: weathersit, dtype: float64

# %%
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])

plt.scatter(bike_sharing["workingday"],bike_sharing["casual"])
plt.title("Working Day Vs. Casual")
plt.show()

plt.scatter(bike_sharing["workingday"],bike_sharing["registered"])
plt.title("Working Day Vs. Registered")
plt.show()

# %%
#bar plot

# %%
working_days = ['Non-Working Day', 'Working Day']
registered_avg = [2959, 3978]

plt.bar(working_days,registered_avg)
# Out:
# <BarContainer object of 2 artists>

# %%
bike_sharing = pd.read_csv('day.csv')
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])
weekday_averages = bike_sharing.groupby('weekday').mean()[['casual', 'registered']].reset_index()

# %%
weekday_averages
# Out:
#    weekday       casual   registered
# 0        0  1338.295238  2890.533333
# 1        1   674.133333  3663.990476
# 2        2   556.182692  3954.480769
# 3        3   551.144231  3997.394231
# 4        4   590.961538  4076.298077
# 5        5   752.288462  3938.000000
# 6        6  1465.257143  3085.285714

# %%
plt.bar(weekday_averages['weekday'], weekday_averages['registered'])
plt.xticks(ticks=[0, 1, 2, 3, 4, 5, 6],
          labels=['Sunday', 'Monday', 'Tuesday', 'Wednesday',
                 'Thursday', 'Friday', 'Saturday'], rotation=30)
plt.show()

# %%
unique_values = [1, 2, 3, 4]
weather_2011 = [226, 124, 15, 0]
weather_2012 = [237, 123, 6, 0]

plt.bar(unique_values, weather_2011)
plt.xticks(ticks=[1,2,3,4])
plt.title('Weather Patterns: 2011')
plt.ylabel('Frequency')
plt.xlabel('Unique Values')
plt.show()

plt.bar(unique_values, weather_2012)
plt.xticks(ticks=[1,2,3,4])
plt.title('Weather Patterns: 2012')
plt.ylabel('Frequency')
plt.xlabel('Unique Values')
plt.show()

# %% [markdown]
# ### histogram(bins)

# %%
import pandas as pd
import matplotlib.pyplot as plt

bike_sharing = pd.read_csv('day.csv')

bike_sharing
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
registered_freq=(bike_sharing['registered'].value_counts(bins=10).sort_index())
casual_freq=(bike_sharing['casual'].value_counts(bins=10).sort_index())


# instances when count of these entity lies within bin

# %%
registered_freq
# Out:
# registered
# (13.073, 712.6]      14
# (712.6, 1405.2]      44
# (1405.2, 2097.8]     79
# (2097.8, 2790.4]     80
# (2790.4, 3483.0]    113
# (3483.0, 4175.6]    144
# (4175.6, 4868.2]     85
# (4868.2, 5560.8]     71
# (5560.8, 6253.4]     57
# (6253.4, 6946.0]     44
# Name: count, dtype: int64

# %%
casual_freq
# Out:
# casual
# (-1.4089999999999998, 342.8]    204
# (342.8, 683.6]                  144
# (683.6, 1024.4]                 165
# (1024.4, 1365.2]                 89
# (1365.2, 1706.0]                 44
# (1706.0, 2046.8]                 23
# (2046.8, 2387.6]                 26
# (2387.6, 2728.4]                 22
# (2728.4, 3069.2]                  9
# (3069.2, 3410.0]                  5
# Name: count, dtype: int64

# %%
## 6. Histograms ##

import pandas as pd
import matplotlib.pyplot as plt

bike_sharing = pd.read_csv('day.csv')
bike_sharing['dteday'] = pd.to_datetime(bike_sharing['dteday'])
casual_freq=(bike_sharing['casual'].value_counts(bins=10).sort_index())
plt.hist(bike_sharing['casual'])
plt.show()

# %%
import pandas
help(pandas.Series.value_counts)
# Out:
# Help on function value_counts in module pandas.core.base:
#
# value_counts(self, normalize: 'bool' = False, sort: 'bool' = True, ascending: 'bool' = False, bins=None, dropna: 'bool' = True) -> 'Series'
#     Return a Series containing counts of unique values.
#
#     The resulting object will be in descending order so that the
#     first element is the most frequently-occurring element.
#     Excludes NA values by default.
#
#     Parameters
#     ----------
#     normalize : bool, default False
#         If True then the object returned will contain the relative
#         frequencies of the unique values.
#     sort : bool, default True
#         Sort by frequencies.
#     ascending : bool, default False
#         Sort in ascending order.
#     bins : int, optional
#         Rather than count values, group them into half-open bins,
#         a convenience for ``pd.cut``, only works with numeric data.
#     dropna : bool, default True
#         Don't include counts of NaN.
#
# ...

# %%
bike_sharing
# Out:
#      instant     dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1 2011-01-01       1   0     1        0        6           0
# 1          2 2011-01-02       1   0     1        0        0           0
# 2          3 2011-01-03       1   0     1        0        1           1
# 3          4 2011-01-04       1   0     1        0        2           1
# 4          5 2011-01-05       1   0     1        0        3           1
# ..       ...        ...     ...  ..   ...      ...      ...         ...
# 726      727 2012-12-27       1   1    12        0        4           1
# 727      728 2012-12-28       1   1    12        0        5           1
# 728      729 2012-12-29       1   1    12        0        6           0
# 729      730 2012-12-30       1   1    12        0        0           0
# 730      731 2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
#Grid Charts

# %%
plt.figure(figsize=(20,24))

# %%
plt.subplot(3, 2, 1)
plt.subplot(3, 2, 2)
plt.subplot(3, 2, 3)
plt.subplot(3, 2, 4)
plt.subplot(3, 2, 5)
plt.subplot(3, 2, 6)
plt.show()

# %%
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_theme()
sns.relplot(data=bike_sharing, x='hum', y='cnt')
plt.show()
# Out:
# /home/t14/Downloads/mygit/dataquest/tenv/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme()
sns.relplot(data=bike_sharing, x='hum', y='cnt',hue='temp', palette='RdYlGn')
plt.show()
# Out:
# /home/t14/Downloads/mygit/dataquest/tenv/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme()
sns.relplot(data=bike_sharing, x='hum', y='cnt',hue='temp',size='windspeed', palette='RdYlGn')
plt.show()
# Out:
# /home/t14/Downloads/mygit/dataquest/tenv/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme()
sns.relplot(data=bike_sharing, x='hum', y='cnt',hue='temp',size='windspeed', palette='RdYlGn', sizes=(1,300),style='holiday', markers=['o','X'])
plt.show()
# Out:
# /home/t14/Downloads/mygit/dataquest/tenv/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme()
sns.relplot(data=bike_sharing, x='hum', y='cnt',hue='temp',size='windspeed', palette='RdYlGn', sizes=(1,300),style='holiday', markers=['o','X'] , col='yr')
plt.show()
# Out:
# /home/t14/Downloads/mygit/dataquest/tenv/lib/python3.8/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
