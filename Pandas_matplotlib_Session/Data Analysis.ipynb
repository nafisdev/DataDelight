# %% [markdown]
# ### Data Sources

# %% [markdown]
# ##### Extraction (E): Data is sourced from various systems, such as databases, APIs, or files.

# %%
pd.read_csv('data.csv')
pd.read_excel('data.xlsx')
sqlite3.connect('database.db')
query = "SELECT * FROM table_name"
pd.read_sql(query, conn)
pd.read_json('data.json')
url = 'https://example.com/table.html'
pd.read_html(url)
df = pd.read_clipboard()

# Using libraries

response = requests.post("https://api.github.com/user/repos", json=payload, headers=headers)
print(response.status_code)
status=response.status_code

# %%
import pandas as pd

data=pd.read_csv("E-commerce Dataset.csv",encoding="latin-1")

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
data
# This is a transnational data set which contains all the transactions occurring between 
#01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.
#The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
# Out:
#        Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0      2018-01-02  10:56:33    8.0        37077  Female         Web
# 1      2018-07-24  20:41:37    2.0        59173  Female         Web
# 2      2018-11-08  08:38:49    8.0        41066  Female         Web
# 3      2018-04-18  19:28:06    7.0        50741  Female         Web
# 4      2018-08-13  21:18:39    9.0        53639  Female         Web
# ...           ...       ...    ...          ...     ...         ...
# 51285  2018-02-28  22:59:50    6.0        78489  Female      Mobile
# 51286  2018-02-28  13:19:25    2.0        91941  Female      Mobile
# 51287  2018-02-28  10:25:07    6.0        63313    Male         Web
# 51288  2018-02-28  10:50:08    7.0        86485    Male         Web
# 51289  2018-02-28  11:09:40    5.0        81129    Male         Web
#
#       Customer_Login_type    Product_Category            Product  Sales  \
# 0                  Member  Auto & Accessories  Car Media Players  140.0
# ...

# %% [markdown]
# ### Transforming data
#
# #####  Data undergoes cleaning, restructuring, and enrichment

# %%
data.dtypes
# Out:
# Order_Date              object
# Time                    object
# Aging                  float64
# Customer_Id              int64
# Gender                  object
# Device_Type             object
# Customer_Login_type     object
# Product_Category        object
# Product                 object
# Sales                  float64
# Quantity               float64
# Discount               float64
# Profit                 float64
# Shipping_Cost          float64
# Order_Priority          object
# Payment_method          object
# dtype: object

# %%
data.loc[:,"Order_Priority"].astype('string').dtypes
# Out:
# string[python]

# %%
d=data.loc[:,"Order_Priority"].astype('string')

# %%
data.astype({'Order_Priority': 'string'}).dtypes
# Out:
# Order_Date                     object
# Time                           object
# Aging                         float64
# Customer_Id                     int64
# Gender                         object
# Device_Type                    object
# Customer_Login_type            object
# Product_Category               object
# Product                        object
# Sales                         float64
# Quantity                      float64
# Discount                      float64
# Profit                        float64
# Shipping_Cost                 float64
# Order_Priority         string[python]
# Payment_method                 object
# dtype: object

# %%
data.loc[:,"Customer_Id"].value_counts()
# Out:
# Customer_Id
# 95831    6
# 35324    5
# 67971    5
# 51905    5
# 21699    5
#         ..
# 16928    1
# 14225    1
# 49204    1
# 38563    1
# 81129    1
# Name: count, Length: 38997, dtype: int64

# %%
## Indexing

# %%
import numpy as np
index = pd.Index([3, 1, 2, 3, 4, np.nan])

# %%
index.value_counts()
index
# Out:
# Index([3.0, 1.0, 2.0, 3.0, 4.0, nan], dtype='float64')

# %%
midx = pd.MultiIndex(levels=[['llama', 'cow', 'falcon'],

                             ['speed', 'weight', 'length']],

                     codes=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
                            [0, 1, 2, 0, 1, 2, 0, 1, 2]])

# %%
midx
# Out:
# MultiIndex([( 'llama',  'speed'),
#             ( 'llama', 'weight'),
#             ( 'llama', 'length'),
#             (   'cow',  'speed'),
#             (   'cow', 'weight'),
#             (   'cow', 'length'),
#             ('falcon',  'speed'),
#             ('falcon', 'weight'),
#             ('falcon', 'length')],
#            )

# %%
df = pd.DataFrame(index=midx, columns=['big', 'small'],

                  data=[[45, 30], [200, 100], [1.5, 1], [30, 20],

                        [250, 150], [1.5, 0.8], [320, 250],

                        [1, 0.8], [0.3, 0.2]])

# %%
df
# Out:
#                  big  small
# llama  speed    45.0   30.0
#        weight  200.0  100.0
#        length    1.5    1.0
# cow    speed    30.0   20.0
#        weight  250.0  150.0
#        length    1.5    0.8
# falcon speed   320.0  250.0
#        weight    1.0    0.8
#        length    0.3    0.2

# %%
data.loc[0:1,["Order_Date"]]
# Out:
#    Order_Date
# 0  2018-01-02
# 1  2018-07-24

# %%
data.iloc[0:1,0:1]
# Out:
#    Order_Date
# 0  2018-01-02

# %%
data.loc[:,"Time"]=='10:56:33'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: Time, Length: 51290, dtype: bool

# %%
data.loc[data.loc[:,"Time"]=='10:56:33']
# Out:
#    Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0  2018-01-02  10:56:33    8.0        37077  Female         Web
#
#   Customer_Login_type    Product_Category            Product  Sales  Quantity  \
# 0              Member  Auto & Accessories  Car Media Players  140.0       1.0
#
#    Discount  Profit  Shipping_Cost Order_Priority Payment_method
# 0       0.3    46.0            4.6         Medium    credit_card

# %%
type(data.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])

# %%
df.apply(np.sqrt)
# Out:
#      A    B
# 0  2.0  3.0
# 1  2.0  3.0
# 2  2.0  3.0

# %%
df.apply(np.sum, axis=0)
# Out:
# A    12
# B    27
# dtype: int64

# %%
df.apply(np.sum, axis=1)
# Out:
# 0    13
# 1    13
# 2    13
# dtype: int64

# %%
def apply(dis):
    if dis>0.2:
        return True
    else:
        return False

# %%
data.loc[:,"Discount"].apply(apply)
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 51285     True
# 51286    False
# 51287     True
# 51288    False
# 51289     True
# Name: Discount, Length: 51290, dtype: bool

# %%
data["Quantity"]
# Out:
# 0        1.0
# 1        1.0
# 2        5.0
# 3        1.0
# 4        1.0
#         ...
# 51285    4.0
# 51286    5.0
# 51287    1.0
# 51288    1.0
# 51289    5.0
# Name: Quantity, Length: 51290, dtype: float64

# %%
a = ("John", "Charles", "Mike")
b = ("Jenny", "Christy", "Monica")

# %%
x = zip(a, b)

# %%
tuple(x)
# Out:
# (('John', 'Jenny'), ('Charles', 'Christy'), ('Mike', 'Monica'))

# %%
a = zip(data["Quantity"],data["Discount"],data["Sales"])

# %%
tuple(a)
# Out:
# ((1.0, 0.3, 140.0),
#  (1.0, 0.3, 211.0),
#  (5.0, 0.1, 117.0),
#  (1.0, 0.3, 118.0),
#  (1.0, 0.3, 250.0),
#  (1.0, 0.3, 72.0),
#  (1.0, 0.3, 54.0),
#  (5.0, 0.2, 114.0),
#  (5.0, 0.3, 231.0),
#  (1.0, 0.2, 140.0),
#  (4.0, 0.1, 211.0),
#  (4.0, 0.3, 117.0),
#  (1.0, 0.2, 118.0),
#  (1.0, 0.3, 250.0),
#  (4.0, 0.1, 72.0),
#  (1.0, 0.1, 54.0),
#  (1.0, 0.3, 114.0),
#  (5.0, 0.3, 231.0),
#  (1.0, 0.3, 140.0),
#  (1.0, 0.2, 211.0),
#  (5.0, 0.1, 117.0),
#  (1.0, 0.3, 118.0),
#  (4.0, 0.2, 250.0),
#  (4.0, 0.2, 72.0),
#  (1.0, 0.3, 54.0),
#  (4.0, 0.2, 114.0),
#  (1.0, 0.3, 231.0),
#  (1.0, 0.3, 140.0),
#  (1.0, 0.3, 211.0),
#  (1.0, 0.2, 117.0),
#  (1.0, 0.3, 118.0),
#  (1.0, 0.2, 250.0),
#  (4.0, 0.3, 72.0),
#  (4.0, 0.3, 54.0),
#  (4.0, 0.1, 114.0),
#  (1.0, 0.3, 231.0),
#  (5.0, 0.3, 140.0),
#  (4.0, 0.1, 211.0),
#  (1.0, 0.3, 117.0),
#  (5.0, 0.3, 118.0),
#  (5.0, 0.3, 250.0),
#  (5.0, 0.2, 72.0),
#  (5.0, 0.1, 54.0),
#  (4.0, 0.3, 114.0),
#  (4.0, 0.3, 231.0),
# ...

# %%
[(1-y)*x* y for x, y, z in zip(data["Quantity"],data["Discount"],data["Sales"])]
# Out:
# [0.21,
#  0.21,
#  0.45,
#  0.21,
#  0.21,
#  0.21,
#  0.21,
#  0.8,
#  1.05,
#  0.16000000000000003,
#  0.36000000000000004,
#  0.84,
#  0.16000000000000003,
#  0.21,
#  0.36000000000000004,
#  0.09000000000000001,
#  0.21,
#  1.05,
#  0.21,
#  0.16000000000000003,
#  0.45,
#  0.21,
#  0.6400000000000001,
#  0.6400000000000001,
#  0.21,
#  0.6400000000000001,
#  0.21,
#  0.21,
#  0.21,
#  0.16000000000000003,
#  0.21,
#  0.16000000000000003,
#  0.84,
#  0.84,
#  0.36000000000000004,
#  0.21,
#  1.05,
#  0.36000000000000004,
#  0.21,
#  1.05,
#  1.05,
#  0.8,
#  0.45,
#  0.84,
#  0.84,
#  0.21,
#  0.09000000000000001,
#  0.84,
#  1.05,
#  0.09000000000000001,
#  0.09000000000000001,
#  1.05,
#  0.84,
#  0.21,
#  0.21,
#  0.09000000000000001,
#  0.6400000000000001,
#  0.21,
#  0.21,
#  0.21,
#  0.45,
#  0.09000000000000001,
#  0.8,
#  0.21,
#  0.21,
#  0.16000000000000003,
#  0.09000000000000001,
#  0.09000000000000001,
#  0.16000000000000003,
#  0.21,
#  0.84,
#  0.21,
#  0.84,
# ...

# %%
data["test"] = [(1-y)*x* y for x, y, z in zip(data["Quantity"],data["Discount"],data["Sales"])]

# %%
data.drop("test")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1080627/1075200625.py in <module>
# ----> 1 data.drop("test")
#
# NameError: name 'data' is not defined

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1080627/391604064.py in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.loc[:,"Discount"].apply(lambda x : x>0.3)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: Discount, Length: 51290, dtype: bool

# %%
#series dont have assign

# do check if .loc[:,[]] or .loc[:,""]

data.loc[:,["Discount"]].assign(Percentage = lambda x: (x['Discount'] > 0.3))
# Out:
#        Discount  Percentage
# 0           0.3       False
# 1           0.3       False
# 2           0.1       False
# 3           0.3       False
# 4           0.3       False
# ...         ...         ...
# 51285       0.3       False
# 51286       0.2       False
# 51287       0.3       False
# 51288       0.2       False
# 51289       0.3       False
#
# [51290 rows x 2 columns]

# %%
data.loc[data.loc[:,"Discount"].apply(apply)]
# Out:
#        Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0      2018-01-02  10:56:33    8.0        37077  Female         Web
# 1      2018-07-24  20:41:37    2.0        59173  Female         Web
# 3      2018-04-18  19:28:06    7.0        50741  Female         Web
# 4      2018-08-13  21:18:39    9.0        53639  Female         Web
# 5      2018-07-09  21:57:05    8.0        39783  Female         Web
# ...           ...       ...    ...          ...     ...         ...
# 51283  2018-02-28  21:12:03    8.0        64954    Male         Web
# 51284  2018-02-28  11:59:55    5.0        63932    Male         Web
# 51285  2018-02-28  22:59:50    6.0        78489  Female      Mobile
# 51287  2018-02-28  10:25:07    6.0        63313    Male         Web
# 51289  2018-02-28  11:09:40    5.0        81129    Male         Web
#
#       Customer_Login_type    Product_Category            Product  Sales  \
# 0                  Member  Auto & Accessories  Car Media Players  140.0
# ...

# %%
#str
data.loc[:,"Gender"].str.replace("Female","female")
# Out:
# 0        female
# 1        female
# 2        female
# 3        female
# 4        female
#           ...
# 51285    female
# 51286    female
# 51287      Male
# 51288      Male
# 51289      Male
# Name: Gender, Length: 51290, dtype: object

# %%
# Aggregation

# %%
data["Product_Category"].unique()
# Out:
# array(['Auto & Accessories', 'Fashion', 'Electronic', 'Home & Furniture'],
#       dtype=object)

# %%
group = data.groupby("Product_Category")

# %%
group.get_group("Fashion")
# Out:
#        Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 5129   2018-05-07  12:39:10    9.0        53248  Female         Web
# 5130   2018-04-24  23:51:56    5.0        45946  Female         Web
# 5131   2018-10-14  15:39:33    3.0        29872    Male         Web
# 5132   2018-06-25  11:45:19    9.0        13517    Male         Web
# 5133   2018-04-24  14:18:04    2.0        50796    Male         Web
# ...           ...       ...    ...          ...     ...         ...
# 46156  2018-11-11  22:03:25    6.0        80046    Male         Web
# 46157  2018-09-09  13:09:50    6.0        65213    Male         Web
# 46158  2018-01-24  23:18:35    1.0        79795  Female      Mobile
# 46159  2018-07-03  08:21:19    2.0        84567    Male         Web
# 46160  2018-09-02  08:54:48    1.0        78792    Male         Web
#
#       Customer_Login_type Product_Category       Product  Sales  Quantity  \
# 5129               Member          Fashion        Shirts  196.0       3.0
# ...

# %%
group["Sales"].mean()
# Out:
# Product_Category
# Auto & Accessories    146.179104
# Electronic            146.145131
# Fashion               169.457771
# Home & Furniture      127.984907
# Name: Sales, dtype: float64

# %%
import numpy as np
group_mean_max=group["Sales"].agg([np.mean,np.max])
group_mean_max
# Out:
#                           mean   amax
# Product_Category
# Auto & Accessories  146.179104  250.0
# Electronic          146.145131  250.0
# Fashion             169.457771  248.0
# Home & Furniture    127.984907  228.0

# %%
pv_sales = data.pivot_table(values='Sales', index='Product_Category', aggfunc=np.mean, margins=True)

# %%
pv_sales
# Out:
#                          Sales
# Product_Category
# Auto & Accessories  146.179104
# Electronic          146.145131
# Fashion             169.457771
# Home & Furniture    127.984907
# All                 152.340872

# %%
mapping = {'Product_Category': 'Category'}
data.rename(mapping, axis=1)
# Out:
#        Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0      2018-01-02  10:56:33    8.0        37077  Female         Web
# 1      2018-07-24  20:41:37    2.0        59173  Female         Web
# 2      2018-11-08  08:38:49    8.0        41066  Female         Web
# 3      2018-04-18  19:28:06    7.0        50741  Female         Web
# 4      2018-08-13  21:18:39    9.0        53639  Female         Web
# ...           ...       ...    ...          ...     ...         ...
# 51285  2018-02-28  22:59:50    6.0        78489  Female      Mobile
# 51286  2018-02-28  13:19:25    2.0        91941  Female      Mobile
# 51287  2018-02-28  10:25:07    6.0        63313    Male         Web
# 51288  2018-02-28  10:50:08    7.0        86485    Male         Web
# 51289  2018-02-28  11:09:40    5.0        81129    Male         Web
#
#       Customer_Login_type            Category            Product  Sales  \
# 0                  Member  Auto & Accessories  Car Media Players  140.0
# ...

# %%
def sales_label(element):
    if element > 120.0:
        return 'High'
    else:
        return 'Low'

# %%
data['Sales'].map(sales_label)
# Out:
# 0        High
# 1        High
# 2         Low
# 3         Low
# 4        High
#          ...
# 51285    High
# 51286     Low
# 51287    High
# 51288    High
# 51289    High
# Name: Sales, Length: 51290, dtype: object

# %%
data['Sales'].apply(sales_label)
# Out:
# 0        High
# 1        High
# 2         Low
# 3         Low
# 4        High
#          ...
# 51285    High
# 51286     Low
# 51287    High
# 51288    High
# 51289    High
# Name: Sales, Length: 51290, dtype: object

# %%
#melt

# %%
data1= data.head(5)

# %%
data2=data.head(2)

# %%
mdata= data1.merge(data2)

# %%
mdata
# Out:
#    Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0  2018-01-02  10:56:33    8.0        37077  Female         Web
# 1  2018-07-24  20:41:37    2.0        59173  Female         Web
#
#   Customer_Login_type    Product_Category            Product  Sales  Quantity  \
# 0              Member  Auto & Accessories  Car Media Players  140.0       1.0
# 1              Member  Auto & Accessories       Car Speakers  211.0       1.0
#
#    Discount  Profit  Shipping_Cost Order_Priority Payment_method
# 0       0.3    46.0            4.6         Medium    credit_card
# 1       0.3   112.0           11.2         Medium    credit_card

# %%
cdata=pd.concat([data1,data2], axis = 0, ignore_index=True)

# %%
cdata
# Out:
#    Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0  2018-01-02  10:56:33    8.0        37077  Female         Web
# 1  2018-07-24  20:41:37    2.0        59173  Female         Web
# 2  2018-11-08  08:38:49    8.0        41066  Female         Web
# 3  2018-04-18  19:28:06    7.0        50741  Female         Web
# 4  2018-08-13  21:18:39    9.0        53639  Female         Web
# 5  2018-01-02  10:56:33    8.0        37077  Female         Web
# 6  2018-07-24  20:41:37    2.0        59173  Female         Web
#
#   Customer_Login_type    Product_Category            Product  Sales  Quantity  \
# 0              Member  Auto & Accessories  Car Media Players  140.0       1.0
# 1              Member  Auto & Accessories       Car Speakers  211.0       1.0
# 2              Member  Auto & Accessories    Car Body Covers  117.0       5.0
# 3              Member  Auto & Accessories    Car & Bike Care  118.0       1.0
# ...

# %% [markdown]
# ### Cleaning: Describe data cleansing steps like removing duplicates, handling missing values, and correcting data types

# %%
cdata.drop(1, axis=0)
# Out:
#    Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0  2018-01-02  10:56:33    8.0        37077  Female         Web
# 2  2018-11-08  08:38:49    8.0        41066  Female         Web
# 3  2018-04-18  19:28:06    7.0        50741  Female         Web
# 4  2018-08-13  21:18:39    9.0        53639  Female         Web
# 5  2018-01-02  10:56:33    8.0        37077  Female         Web
# 6  2018-07-24  20:41:37    2.0        59173  Female         Web
#
#   Customer_Login_type    Product_Category            Product  Sales  Quantity  \
# 0              Member  Auto & Accessories  Car Media Players  140.0       1.0
# 2              Member  Auto & Accessories    Car Body Covers  117.0       5.0
# 3              Member  Auto & Accessories    Car & Bike Care  118.0       1.0
# 4              Member  Auto & Accessories               Tyre  250.0       1.0
# 5              Member  Auto & Accessories  Car Media Players  140.0       1.0
# ...

# %%
cdata.drop('Aging', axis=1)
# Out:
#    Order_Date      Time  Customer_Id  Gender Device_Type Customer_Login_type  \
# 0  2018-01-02  10:56:33        37077  Female         Web              Member
# 1  2018-07-24  20:41:37        59173  Female         Web              Member
# 2  2018-11-08  08:38:49        41066  Female         Web              Member
# 3  2018-04-18  19:28:06        50741  Female         Web              Member
# 4  2018-08-13  21:18:39        53639  Female         Web              Member
# 5  2018-01-02  10:56:33        37077  Female         Web              Member
# 6  2018-07-24  20:41:37        59173  Female         Web              Member
#
#      Product_Category            Product  Sales  Quantity  Discount  Profit  \
# 0  Auto & Accessories  Car Media Players  140.0       1.0       0.3    46.0
# 1  Auto & Accessories       Car Speakers  211.0       1.0       0.3   112.0
# 2  Auto & Accessories    Car Body Covers  117.0       5.0       0.1    31.2
# ...

# %%
cdata.drop_duplicates(subset=['Product' ,'Gender'])
#We are havig unnique data for product
# Out:
#    Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0  2018-01-02  10:56:33    8.0        37077  Female         Web
# 1  2018-07-24  20:41:37    2.0        59173  Female         Web
# 2  2018-11-08  08:38:49    8.0        41066  Female         Web
# 3  2018-04-18  19:28:06    7.0        50741  Female         Web
# 4  2018-08-13  21:18:39    9.0        53639  Female         Web
#
#   Customer_Login_type    Product_Category            Product  Sales  Quantity  \
# 0              Member  Auto & Accessories  Car Media Players  140.0       1.0
# 1              Member  Auto & Accessories       Car Speakers  211.0       1.0
# 2              Member  Auto & Accessories    Car Body Covers  117.0       5.0
# 3              Member  Auto & Accessories    Car & Bike Care  118.0       1.0
# 4              Member  Auto & Accessories               Tyre  250.0       1.0
#
#    Discount  Profit  Shipping_Cost Order_Priority Payment_method
# ...

# %%
cdata.at[1,"Customer_Id"]= np.nan

# %%
# Detecting Anomalies

# %%
import seaborn as sns

sns.heatmap(cdata.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
cdata.dropna()
# Out:
#    Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0  2018-01-02  10:56:33    8.0      37077.0  Female         Web
# 2  2018-11-08  08:38:49    8.0      41066.0  Female         Web
# 3  2018-04-18  19:28:06    7.0      50741.0  Female         Web
# 4  2018-08-13  21:18:39    9.0      53639.0  Female         Web
# 5  2018-01-02  10:56:33    8.0      37077.0  Female         Web
# 6  2018-07-24  20:41:37    2.0      59173.0  Female         Web
#
#   Customer_Login_type    Product_Category            Product  Sales  Quantity  \
# 0              Member  Auto & Accessories  Car Media Players  140.0       1.0
# 2              Member  Auto & Accessories    Car Body Covers  117.0       5.0
# 3              Member  Auto & Accessories    Car & Bike Care  118.0       1.0
# 4              Member  Auto & Accessories               Tyre  250.0       1.0
# 5              Member  Auto & Accessories  Car Media Players  140.0       1.0
# ...
